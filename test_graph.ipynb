# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False

# %%
train = [0.8474316616544584,0.8474316616544584,0.8474316616544584]
pre = [0.7295903413522566, 0.6953124637185857, 0.6986921397680189]
day = [1,2,3]
df = pd.DataFrame({'pre':pre, 'day':day})
df = df.set_index('day')
df
# Out:
#           pre
# day
# 1    0.729590
# 2    0.695312
# 3    0.698692

# %%
plt.figure(figsize=(7,5), dpi = 200)
plt.plot(day,train, label='train')
plt.plot(day,pre, label='test')
# plt.axhline(0.8474316616544584, 0, 3, color='r', linestyle='-', linewidth=2)
plt.ylim(0.4,1)
plt.yticks([0.4,0.6,0.8,0.85,1.0])
plt.xticks([1,2,3])
plt.legend(loc='lower right', fontsize=12)
# plt.text(1,train[0],str(0.85),
#          fontsize=12,
#          color='k',
#         horizontalalignment='center',
#         verticalalignment='bottom')

for i, v in enumerate(day):
    plt.text(v, pre[i], str(round(pre[i],2)),
             fontsize=12,
             color="k",
             horizontalalignment='center',
             verticalalignment='bottom')


# plt.title('결정계수', fontsize=14)
plt.xlabel('O일후 예보', fontsize=12)
plt.ylabel('결정계수', fontsize=12)
plt.savefig('result_predict.png', facecolor='w', bbox_inches='tight')
plt.show()
